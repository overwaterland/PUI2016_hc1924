# %%
import pandas as pd
import os

# %%
DFdata = os.getenv('DFDATA')
DFdata
# Out:
# '/gws/open/NYCOpenData/nycopendata/data'

# %%
# NYPD Motor Vehicle Collisions h9gi-nx95 CSV
mcollision = pd.read_csv(DFdata + "/h9gi-nx95/1428430582/h9gi-nx95")
mcollision.columns
# Out:
# Index([u'DATE', u'TIME', u'BOROUGH', u'ZIP CODE', u'LATITUDE', u'LONGITUDE',
#        u'LOCATION', u'ON STREET NAME', u'CROSS STREET NAME',
#        u'OFF STREET NAME', u'NUMBER OF PERSONS INJURED',
#        u'NUMBER OF PERSONS KILLED', u'NUMBER OF PEDESTRIANS INJURED',
#        u'NUMBER OF PEDESTRIANS KILLED', u'NUMBER OF CYCLIST INJURED',
#        u'NUMBER OF CYCLIST KILLED', u'NUMBER OF MOTORIST INJURED',
#        u'NUMBER OF MOTORIST KILLED', u'CONTRIBUTING FACTOR VEHICLE 1',
#        u'CONTRIBUTING FACTOR VEHICLE 2', u'CONTRIBUTING FACTOR VEHICLE 3',
#        u'CONTRIBUTING FACTOR VEHICLE 4', u'CONTRIBUTING FACTOR VEHICLE 5',
#        u'UNIQUE KEY', u'VEHICLE TYPE CODE 1', u'VEHICLE TYPE CODE 2',
#        u'VEHICLE TYPE CODE 3', u'VEHICLE TYPE CODE 4', u'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
mcollision.head()
# Out:
#          DATE   TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  04/04/2015   9:25  MANHATTAN   10001.0  40.750788 -74.005630
# 1  04/04/2015  21:15     QUEENS   11357.0  40.781291 -73.814200
# 2  04/04/2015  16:52     QUEENS   11385.0  40.702595 -73.855293
# 3  04/04/2015   9:30  MANHATTAN   10025.0  40.804886 -73.962474
# 4  04/04/2015   9:41     QUEENS   11428.0  40.715144 -73.749356
#
#                     LOCATION       ON STREET NAME CROSS STREET NAME  \
# 0  (40.7507879, -74.0056304)       WEST 26 STREET         11 AVENUE
# 1  (40.7812915, -73.8141997)            20 AVENUE        150 STREET
# 2  (40.7025952, -73.8552926)  WOODHAVEN BOULEVARD     MYRTLE AVENUE
# 3  (40.8048862, -73.9624735)      WEST 113 STREET  AMSTERDAM AVENUE
# 4  (40.7151436, -73.7493556)           211 STREET    JAMAICA AVENUE
#
#   OFF STREET NAME         ...          CONTRIBUTING FACTOR VEHICLE 2  \
# 0             NaN         ...                            Unspecified
# 1             NaN         ...                            Unspecified
# 2             NaN         ...                            Unspecified
# 3             NaN         ...                            Unspecified
# 4             NaN         ...                                    NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY  VEHICLE TYPE CODE 1  \
# 0                            NaN     3197298        PICK-UP TRUCK
# 1                            NaN     3198105    PASSENGER VEHICLE
# 2                            NaN     3197589    PASSENGER VEHICLE
# 3                            NaN     3197369    PASSENGER VEHICLE
# 4                            NaN     3197601    PASSENGER VEHICLE
#
#    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0       LIVERY VEHICLE                  NaN                 NaN
# 1    PASSENGER VEHICLE                  NaN                 NaN
# 2                OTHER                  NaN                 NaN
# 3              UNKNOWN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
#   VEHICLE TYPE CODE 5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %%
mcollision.drop([u'DATE', u'TIME', u'BOROUGH', u'ZIP CODE',u'LOCATION', u'ON STREET NAME', u'CROSS STREET NAME',
       u'OFF STREET NAME', u'NUMBER OF PERSONS INJURED',
       u'NUMBER OF PERSONS KILLED', u'NUMBER OF PEDESTRIANS INJURED',
       u'NUMBER OF PEDESTRIANS KILLED', u'NUMBER OF CYCLIST INJURED',
       u'NUMBER OF CYCLIST KILLED', u'NUMBER OF MOTORIST INJURED',
       u'NUMBER OF MOTORIST KILLED', u'CONTRIBUTING FACTOR VEHICLE 1',
       u'CONTRIBUTING FACTOR VEHICLE 2', u'CONTRIBUTING FACTOR VEHICLE 3',
       u'CONTRIBUTING FACTOR VEHICLE 4', u'CONTRIBUTING FACTOR VEHICLE 5',
       u'UNIQUE KEY', u'VEHICLE TYPE CODE 1', u'VEHICLE TYPE CODE 2',
       u'VEHICLE TYPE CODE 3', u'VEHICLE TYPE CODE 4', u'VEHICLE TYPE CODE 5'], axis = 1)
# Out:
#          LATITUDE  LONGITUDE
# 0       40.750788 -74.005630
# 1       40.781291 -73.814200
# 2       40.702595 -73.855293
# 3       40.804886 -73.962474
# 4       40.715144 -73.749356
# 5       40.687945 -73.981401
# 6       40.766886 -73.823951
# 7             NaN        NaN
# 8       40.626362 -74.008300
# 9       40.763942 -73.828146
# 10      40.769270 -73.969364
# 11      40.749472 -73.756393
# 12            NaN        NaN
# 13      40.631464 -74.027792
# 14      40.674292 -73.800636
# 15      40.780147 -73.847848
# 16      40.745392 -73.905580
# 17            NaN        NaN
# 18      40.829502 -73.874609
# 19      40.560249 -74.169735
# 20      40.691868 -73.858828
# 21      40.753450 -73.827451
# 22      40.882709 -73.881246
# 23            NaN        NaN
# 24            NaN        NaN
# 25            NaN        NaN
# 26      40.680027 -73.839965
# 27      40.669434 -73.925492
# 28      40.674742 -73.997769
# 29      40.760353 -73.991232
# ...           ...        ...
# 561920  40.720321 -73.994040
# 561921  40.768916 -73.888727
# 561922        NaN        NaN
# 561923        NaN        NaN
# 561924  40.777661 -73.795016
# 561925        NaN        NaN
# 561926  40.597027 -73.953149
# 561927  40.716453 -74.013048
# 561928  40.747925 -73.973607
# 561929  40.715310 -73.826381
# 561930  40.576827 -73.965096
# 561931  40.526266 -74.201526
# 561932        NaN        NaN
# 561933  40.765991 -73.987123
# 561934  40.710161 -73.988533
# 561935  40.824392 -73.836293
# 561936  40.579813 -73.837199
# 561937  40.708627 -73.945124
# 561938  40.708627 -73.945124
# 561939  40.577995 -73.959635
# 561940  40.727873 -73.929122
# 561941  40.747629 -73.976736
# 561942  40.708627 -73.945124
# 561943        NaN        NaN
# 561944  40.711801 -73.942229
# 561945  40.704798 -74.016685
# 561946  40.578937 -73.985212
# 561947  40.757847 -73.899213
# 561948        NaN        NaN
# 561949  40.842119 -73.832903
#
# [561950 rows x 2 columns]

# %%
import pylab as pl
# %pylab inline
ax = mcollision.plot(x='LONGITUDE', y='LATITUDE', kind="scatter", alpha=0.01,figsize = (8,8))
ax.set_title("All Motor Collisions")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-52-085c0287ecb5> in <module>()
# ----> 1 import seaborn
#
# ImportError: No module named seaborn
